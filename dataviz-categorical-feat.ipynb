# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('heart.csv')

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df_cat = df.select_dtypes(include='object')

# %%
df_cat.columns
# Out:
# Index(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], dtype='object')

# %%
sns.histplot(df.Sex)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Count'>

# %%
sns.histplot(df.ChestPainType)
# Out:
# <AxesSubplot:xlabel='ChestPainType', ylabel='Count'>

# %%
sns.histplot(df.RestingECG)
# Out:
# <AxesSubplot:xlabel='RestingECG', ylabel='Count'>

# %%
sns.histplot(df.ExerciseAngina)
# Out:
# <AxesSubplot:xlabel='ExerciseAngina', ylabel='Count'>

# %%
sns.histplot(df.ST_Slope)
# Out:
# <AxesSubplot:xlabel='ST_Slope', ylabel='Count'>

# %%
sns.histplot(x='ChestPainType', data = df, hue = 'Sex')
plt.show()

# %%
sns.histplot(x='ChestPainType', data = df, hue = 'Age',cbar=True)
plt.show()
